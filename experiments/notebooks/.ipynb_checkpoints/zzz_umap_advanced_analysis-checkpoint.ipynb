# %%
import numpy as np
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import umap.umap_ as umap
# %matplotlib inline
sns.set(style='white', context='notebook', rc={'figure.figsize':(14,10)})

# %%
data = pd.read_csv('..\\data\\analysis_dataset_w_material.csv', sep=";")

# %%
#fillratio
fill_ratio = 100 - data.isnull().sum(axis = 0)/len(data)*100
print(fill_ratio)
# Out:
# Unnamed: 0        100.000000
# coin              100.000000
# maxdiam            75.257983
# mindiam            44.650506
# weight             86.073793
# material           98.259833
# enddate            81.082068
# startdate          81.077200
# axis               34.703563
# findspot          100.000000
# material_cat      100.000000
# denom_cat         100.000000
# mint_cat          100.000000
# collection_cat    100.000000
# dtype: float64

# %%
#axi and mindiam very low fill ratio
del data["mindiam"]
del data["axis"]
data = data.dropna()
data.shape
# Out:
# (24088, 12)

# %%
#scale data and join entities
del data["findspot"]
coins = data["coin"].to_list()
data["material"] = data["material"].astype("category")
data["material"] = data["material"].cat.codes
for c in data.columns:
    try:
        data[c] = data[c].astype(float)
    except:
        print(c)
del data["coin"]
scaled_data = StandardScaler().fit_transform(data)
scaled_data = pd.DataFrame(scaled_data)
scaled_data["coin"] = coins
design_data = pd.read_csv("..\\2021_06_01_DC_NLP_CNT\\design_dummys.csv", sep=";")
complete_data = pd.merge(scaled_data, design_data, how="left", left_on="coin", right_on="id_coin")
print(complete_data.shape)
# Out:
# (24088, 583)

# %%
complete_data = complete_data.dropna()
coins = complete_data["coin"]
del complete_data["coin"]
print(complete_data.shape)
# Out:
# (19875, 582)

# %%
r2 = umap.UMAP(random_state=42)
r2.fit(complete_data)
embedding = r2.transform(complete_data)
# Out:
# c:\users\fredi\anaconda3\envs\ftp\lib\site-packages\sklearn\manifold\_spectral_embedding.py:236: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"

# %%
print(embedding.shape)
plt.scatter(
    embedding[:, 0],
    embedding[:, 1])
plt.gca().set_aspect('equal', 'datalim')
# Out:
# (19875, 2)

# %%
from sklearn.mixture import GaussianMixture

# %%
bic_score = []
aic_score = []
n_range = range(2, 20)
for n in n_range:
    gm = GaussianMixture(n_components=n, 
                         random_state=123, 
                         n_init=10)
    gm.fit(embedding)
    
    # Append the BIC and AIC to the respective lists
    bic_score.append(gm.bic(embedding))
    aic_score.append(gm.aic(embedding))
    
# Plot the BIC and AIC values together
fig, ax = plt.subplots(figsize=(12,8),nrows=1)
ax.plot(n_range, bic_score, '-o', color='orange')
ax.plot(n_range, aic_score, '-o', color='green')
ax.set(xlabel='Number of Clusters', ylabel='Score')
ax.set_xticks(n_range)
ax.set_title('BIC and AIC Scores Per Number Of Clusters')
# Out:
# Text(0.5, 1.0, 'BIC and AIC Scores Per Number Of Clusters')

# %%
gm = GaussianMixture(n_components=10, 
                     random_state=123, 
                     n_init=10)
gm.fit(embedding)
labels = gm.predict(embedding)

plt.scatter(
    embedding[:, 0],
    embedding[:, 1], c=labels,  cmap='Spectral')
plt.gca().set_aspect('equal', 'datalim')

# %%
result_df = pd.DataFrame({"coin": coins, "label": labels})
result_df["coin"] = result_df["coin"].astype(int)

# %%
data_total = pd.read_csv('..\\data\\analysis_dataset_w_material.csv', sep=";")
data_entity = pd.read_csv("..\\2021_06_01_DC_NLP_CNT\\design_data2.csv", sep=";")
data_entity = data_entity[data_entity["Label_Entity"]!="VERBS"]
for i in range(10):
    result_df_sample = result_df[result_df["label"]==i]
    coin_sample = result_df_sample["coin"].to_list()
    data_entity_sample = data_entity[data_entity["id_coin"].isin(coin_sample)]
    data_sample = data_total[data_total["coin"].isin(coin_sample)]
    print("#"*10)
    print(f"Cluster {i}")
    print(data_sample.describe())
    data_entity_agg = data_entity_sample.groupby("Entity")["id_coin"].count().reset_index()
    data_entity_agg = data_entity_agg.sort_values("id_coin", ascending=False)
    print(data_entity_agg.head(20))
# Out:
# ##########
# Cluster 0
#          Unnamed: 0          coin      maxdiam      mindiam       weight  \
# count   1625.000000   1625.000000  1625.000000  1422.000000  1625.000000
# mean   20599.113231  11307.354462    20.126172    19.879592     7.048474
# std    11702.516041  11135.690960     6.502319     6.396083     5.239312
# min       60.000000   6363.000000     7.000000     8.000000     0.450000
# 25%    10299.000000   6811.000000    15.000000    14.000000     2.590000
# 50%    20619.000000   7309.000000    20.000000    20.000000     6.070000
# 75%    30305.000000   7940.000000    25.000000    25.000000    10.410000
# max    41052.000000  41902.000000    42.000000    42.000000    60.310000
#
#            enddate    startdate         axis  material_cat    denom_cat  \
# count  1625.000000  1625.000000  1055.000000   1625.000000  1625.000000
# mean   -124.270154  -161.395692     7.579147      0.433846    13.748923
# std     256.020012   267.270143     4.038611      0.528229    15.622580
# min    -500.000000  -540.000000     1.000000      0.000000    -1.000000
# 25%    -336.000000  -365.000000     5.000000      0.000000     0.000000
# 50%    -215.000000  -286.000000     7.000000      0.000000     4.000000
# 75%     210.000000   193.000000    12.000000      1.000000    25.000000
# max     300.000000   253.000000    12.000000      4.000000    51.000000
#
#           mint_cat  collection_cat
# count  1625.000000     1625.000000
# mean     47.641231    18477.163692
# std      33.037762    10868.411087
# min      -1.000000       -1.000000
# 25%      15.000000     9030.000000
# 50%      52.000000    18418.000000
# 75%      70.000000    28039.000000
# max     115.000000    37215.000000
#            Entity  id_coin
# 117          Kopf     1095
# 134  Lorbeerkranz      475
# 26      Brustbild      391
# 308       haltend      322
# 165  Paludamentum      313
# 297       erhoben      290
# 328       stehend      284
# 85          Greif      276
# 168        Panzer      275
# 97       Herakles      239
# 78         Gewand      232
# 10        Apollon      209
# 140     Löwenfell      206
# 83        Gordian      188
# 14         Athena      150
# 282        Zepter      149
# 332      thronend      148
# 326     springend      145
# 45       Dionysos      141
# 95           Helm      137
# ##########
# Cluster 1
#          Unnamed: 0          coin      maxdiam      mindiam       weight  \
# count   1945.000000   1945.000000  1945.000000  1491.000000  1945.000000
# mean   20499.014910  25821.305913    22.533974    21.277995     8.662900
# std    11823.906126  11055.275436     5.621585     5.208270     5.963993
# min       30.000000     41.000000     4.630000     8.100000     0.060000
# 25%    10226.000000  27055.000000    18.300000    17.300000     3.970000
# 50%    20420.000000  31872.000000    21.700000    19.200000     5.960000
# 75%    31041.000000  32540.000000    27.000000    25.500000    13.940000
# max    41051.000000  33131.000000    46.000000    39.000000    59.550000
#
#            enddate    startdate        axis  material_cat   denom_cat  \
# count  1945.000000  1945.000000  447.000000   1945.000000  1945.00000
# mean     67.681234    45.328535    7.449664      0.205141     9.25347
# std     213.183877   223.936229    3.706320      0.406448    14.88730
# min    -460.000000  -513.000000    1.000000      0.000000    -1.00000
# 25%    -197.000000  -241.000000    6.000000      0.000000     1.00000
# 50%     192.000000   177.000000    7.000000      0.000000     3.00000
# 75%     211.000000   193.000000   12.000000      0.000000     4.00000
# max     268.000000   253.000000   12.000000      2.000000    51.00000
#
#           mint_cat  collection_cat
# count  1945.000000     1945.000000
# mean     70.198972    17168.920823
# std      25.193592    11552.800499
# min      -1.000000       -1.000000
# 25%      60.000000     6629.000000
# 50%      86.000000    17229.000000
# 75%      86.000000    27124.000000
# max     101.000000    37198.000000
#                 Entity  id_coin
# 127       Lorbeerkranz     1148
# 113               Kopf     1110
# 27           Brustbild      911
# 275            haltend      542
# 157       Paludamentum      505
# 159             Panzer      501
# 160             Patera      370
# 201  Septimius Severus      364
# 77              Gewand      326
# 191             Schild      311
# 37            Commodus      308
# 291            stehend      302
# 294           thronend      265
# 13              Athena      262
# 8              Apollon      236
# 116              Kranz      226
# 67            Füllhorn      189
# 106           Kalathos      157
# 265            erhoben      155
# 209              Speer      152
# ##########
# Cluster 2
#          Unnamed: 0          coin      maxdiam      mindiam       weight  \
# count   2283.000000   2283.000000  2283.000000  1509.000000  2283.000000
# mean   20362.030223  13234.925975    20.868419    19.535195     7.764717
# std    11899.001706   6120.762962     6.952666     6.251129     6.677040
# min       32.000000   1593.000000     6.600000     6.200000     0.190000
# 25%    10113.500000  15206.500000    15.500000    15.000000     2.910000
# 50%    20379.000000  15931.000000    20.000000    18.500000     5.220000
# 75%    30782.000000  16726.500000    25.000000    23.800000    12.430000
# max    41078.000000  22596.000000    60.000000    41.000000    93.340000
#
#            enddate    startdate        axis  material_cat    denom_cat  \
# count  2283.000000  2283.000000  847.000000   2283.000000  2283.000000
# mean    -74.683311  -133.241787    8.132231      0.339904     8.850197
# std     224.118675   234.024425    3.669759      0.590694    15.697161
# min    -550.000000  -600.000000    1.000000      0.000000    -1.000000
# 25%    -300.000000  -350.000000    6.000000      0.000000    -1.000000
# 50%     -49.000000  -189.000000    7.000000      0.000000    -1.000000
# 75%     138.000000    98.000000   12.000000      1.000000    18.000000
# max     299.000000   261.000000   12.000000      4.000000    51.000000
#
#           mint_cat  collection_cat
# count  2283.000000     2283.000000
# mean     49.296102    17725.374945
# std      29.389433    11132.644768
# min      -1.000000       -1.000000
# 25%      27.000000     7715.000000
# 50%      53.000000    17690.000000
# 75%      69.000000    27468.000000
# max     115.000000    37179.000000
#            Entity  id_coin
# 123          Kopf     1341
# 138  Lorbeerkranz      688
# 54       Dionysos      640
# 32      Brustbild      511
# 180         Pferd      394
# 59      Efeukranz      357
# 275    Weintraube      326
# 228       Speeren      271
# 170  Paludamentum      240
# 83         Gewand      231
# 1           Adler      223
# 177       Petasos      219
# 14        Apollon      217
# 315       stehend      209
# 273      Weinrebe      207
# 173        Panzer      205
# 297       haltend      181
# 181       Pferdes      174
# 279          Zeus      157
# 262       Trauben      147
# ##########
# Cluster 3
#          Unnamed: 0          coin      maxdiam     mindiam       weight  \
# count   2134.000000   2134.000000  2134.000000  467.000000  2134.000000
# mean   20674.783974  31307.253046    18.420173   19.829186     7.778763
# std    11958.412554   9497.821021     6.798164    6.635728     7.087882
# min       14.000000  10183.000000     6.000000    6.800000     0.300000
# 25%    10260.000000  20742.250000    12.000000   15.000000     2.422500
# 50%    20259.500000  38201.500000    18.000000   18.600000     4.990000
# 75%    31079.750000  39123.750000    23.175000   24.000000    12.560000
# max    41085.000000  42036.000000    44.000000   42.000000    44.910000
#
#            enddate    startdate        axis  material_cat    denom_cat  \
# count  2134.000000  2134.000000  792.000000   2134.000000  2134.000000
# mean   -215.081537  -260.733833    8.204545      1.077320    15.340675
# std     224.109473   231.740661    3.750915      1.448643    18.039589
# min    -550.000000  -600.000000    1.000000      0.000000    -1.000000
# 25%    -407.000000  -412.000000    6.000000      0.000000    -1.000000
# 50%    -300.000000  -350.000000    9.000000      1.000000    11.000000
# 75%     -50.000000  -100.000000   12.000000      1.000000    38.000000
# max     300.000000   253.000000   12.000000      4.000000    51.000000
#
#           mint_cat  collection_cat
# count  2134.000000     2134.000000
# mean     42.436739    14499.127460
# std      29.042276    12294.890574
# min      -1.000000       -1.000000
# 25%      17.000000     1257.500000
# 50%      38.000000    13189.500000
# 75%      69.000000    25452.000000
# max     111.000000    37204.000000
#            Entity  id_coin
# 122          Kopf     1485
# 137  Lorbeerkranz      596
# 246     Thunfisch      376
# 10        Apollon      281
# 101        Hermes      271
# 180       Petasos      256
# 47       Dionysos      237
# 56      Efeukranz      224
# 276    Ziegenbock      221
# 27      Brustbild      215
# 313       stehend      196
# 14         Athena      165
# 207      Schlange      160
# 295       haltend      160
# 144         Löwen      148
# 23          Bogen      146
# 98           Helm      139
# 320        windet      128
# 208     Schlangen      127
# 37          Cista      126
# ##########
# Cluster 4
#          Unnamed: 0          coin      maxdiam      mindiam       weight  \
# count   2084.000000   2084.000000  2084.000000  1792.000000  2084.000000
# mean   20716.245202   6261.009117    22.523369    23.293471     9.945010
# std    12017.475953   6405.191177     8.227557     8.094236     9.045103
# min       11.000000   2508.000000     6.000000     6.000000     0.310000
# 25%    10080.750000   3214.750000    16.000000    17.000000     3.007500
# 50%    20898.000000   3845.500000    22.000000    23.000000     7.080000
# 75%    31168.500000   4610.250000    28.000000    29.000000    14.690000
# max    41083.000000  41348.000000    44.100000    44.100000    55.090000
#
#            enddate    startdate         axis  material_cat    denom_cat  \
# count  2084.000000  2084.000000  1244.000000   2084.000000  2084.000000
# mean    -40.015835   -70.920825     7.062701      0.443378    11.560461
# std     267.346105   280.229712     3.838987      0.948081    16.791103
# min    -550.000000  -600.000000     1.000000      0.000000    -1.000000
# 25%    -350.000000  -377.000000     5.000000      0.000000    -1.000000
# 50%      41.000000    37.500000     7.000000      0.000000     3.000000
# 75%     213.250000   197.000000    12.000000      1.000000    18.000000
# max     268.000000   253.000000    12.000000      4.000000    51.000000
#
#           mint_cat  collection_cat
# count  2084.000000     2084.000000
# mean     54.797985    18944.738484
# std      31.747912    10696.938433
# min      -1.000000       -1.000000
# 25%      24.000000     9896.750000
# 50%      69.000000    18942.500000
# 75%      84.000000    28198.500000
# max     111.000000    37214.000000
#            Entity  id_coin
# 141          Kopf      981
# 161  Lorbeerkranz      791
# 28      Brustbild      775
# 196        Panzer      513
# 193  Paludamentum      474
# 372       stehend      285
# 198        Patera      259
# 324    Weintraube      252
# 350       haltend      221
# 34      Caracalla      213
# 212       Pferdes      203
# 230        Ranken      188
# 97         Gewand      182
# 50         Diadem      166
# 54       Dionysos      165
# 326        Zepter      157
# 82       Füllhorn      156
# 268         Speer      150
# 118        Hermes      142
# 117      Herakles      140
# ##########
# Cluster 5
#          Unnamed: 0          coin      maxdiam      mindiam       weight  \
# count   1705.000000   1705.000000  1705.000000  1460.000000  1705.000000
# mean   20477.350147   8412.813490    22.833953    22.318562     9.798299
# std    11952.320317   4969.761627     7.622162     7.503119     8.042095
# min       65.000000   4942.000000     0.700000     0.700000     0.120000
# 25%    10085.000000   5469.000000    17.000000    16.400000     3.400000
# 50%    20734.000000   5922.000000    23.000000    22.000000     8.390000
# 75%    30695.000000  14160.000000    28.000000    28.000000    14.400000
# max    41018.000000  24914.000000    47.000000    45.000000    47.810000
#
#            enddate    startdate         axis  material_cat    denom_cat  \
# count  1705.000000  1705.000000  1065.000000   1705.000000  1705.000000
# mean    -31.304399   -66.086804     6.752113      0.347801    13.612317
# std     259.834869   275.984917     3.819784      0.545336    17.463892
# min    -500.000000  -600.000000     1.000000      0.000000    -1.000000
# 25%    -325.000000  -365.000000     4.000000      0.000000    -1.000000
# 50%      68.000000    54.000000     7.000000      0.000000     3.000000
# 75%     217.000000   197.000000    11.000000      1.000000    25.000000
# max     400.000000   300.000000    12.000000      4.000000    51.000000
#
#           mint_cat  collection_cat
# count  1705.000000     1705.000000
# mean     53.690909    18613.199413
# std      38.549783    10876.015836
# min      -1.000000       -1.000000
# 25%      10.000000     9348.000000
# 50%      69.000000    18677.000000
# 75%      84.000000    27873.000000
# max     112.000000    37224.000000
#            Entity  id_coin
# 131          Kopf     1029
# 146  Lorbeerkranz      778
# 31      Brustbild      595
# 183        Panzer      384
# 180  Paludamentum      380
# 340       stehend      370
# 36      Caracalla      326
# 51       Dionysos      284
# 318       haltend      280
# 92         Gewand      209
# 13        Apollon      200
# 0           Adler      193
# 109      Herakles      185
# 59      Efeukranz      184
# 185        Patera      170
# 192         Pferd      165
# 291      Weinrebe      153
# 293    Weintraube      153
# 280       Trauben      142
# 127         Keule      139
# ##########
# Cluster 6
#          Unnamed: 0          coin      maxdiam      mindiam       weight  \
# count   1828.000000   1828.000000  1828.000000  1060.000000  1828.000000
# mean   20676.529540  21029.462801    20.811433    21.522736     7.902188
# std    11813.540702  12008.828507     7.156546     7.106786     6.552279
# min        6.000000   9047.000000     2.600000     7.000000     0.520000
# 25%    10563.250000   9793.750000    15.000000    16.000000     2.740000
# 50%    20672.000000  18261.500000    19.200000    21.000000     5.265000
# 75%    31114.250000  37279.250000    27.125000    28.400000    13.160000
# max    41065.000000  40684.000000    49.000000    42.000000    49.620000
#
#            enddate    startdate        axis  material_cat    denom_cat  \
# count  1828.000000  1828.000000  823.000000   1828.000000  1828.000000
# mean    -19.655908   -54.189278    8.643985      0.280635     8.735777
# std     232.323075   248.645441    3.811669      0.790278    15.813316
# min    -550.000000  -600.000000    1.000000      0.000000    -1.000000
# 25%    -225.000000  -281.000000    6.000000      0.000000    -1.000000
# 50%      -1.000000   -27.000000   11.000000      0.000000     1.000000
# 75%     209.000000   193.000000   12.000000      0.000000    10.000000
# max     300.000000   258.000000   12.000000      4.000000    51.000000
#
#           mint_cat  collection_cat
# count  1828.000000     1828.000000
# mean     50.502735    17389.916302
# std      33.534198    11353.469715
# min      -1.000000       -1.000000
# 25%      20.000000     6956.000000
# 50%      38.000000    17298.000000
# 75%      83.000000    27011.250000
# max     114.000000    37221.000000
#             Entity  id_coin
# 135           Kopf     1503
# 153   Lorbeerkranz      848
# 33       Brustbild      615
# 349        stehend      481
# 325        haltend      369
# 189         Panzer      357
# 185   Paludamentum      343
# 107           Helm      329
# 19          Athena      297
# 91          Gewand      289
# 38       Caracalla      226
# 191         Patera      179
# 18       Asklepios      178
# 322       gestützt      172
# 230       Schlange      162
# 303           Zeus      133
# 232  Schlangenstab      117
# 339     schreitend      116
# 184      Palmzweig      116
# 124       Kalathos      105
# ##########
# Cluster 7
#          Unnamed: 0          coin      maxdiam      mindiam       weight  \
# count   1931.000000   1931.000000  1931.000000  1729.000000  1931.000000
# mean   20586.973071   7000.949767    21.203107    20.736842     7.605034
# std    11903.238806  10980.077914     6.564577     6.442061     6.606631
# min        9.000000    253.000000     6.000000     7.000000     0.270000
# 25%    10308.500000    807.500000    17.000000    16.000000     3.275000
# 50%    20589.000000   1368.000000    21.000000    20.000000     5.440000
# 75%    31219.000000   1911.500000    25.900000    25.000000    10.005000
# max    41081.000000  34575.000000    43.000000    41.000000    64.320000
#
#            enddate    startdate        axis  material_cat    denom_cat  \
# count  1931.000000  1931.000000  656.000000   1931.000000  1931.000000
# mean    -17.984982   -65.293630    7.713415      0.222165     8.053858
# std     253.709385   272.723691    4.053859      0.415809    13.048066
# min    -510.000000  -520.000000    1.000000      0.000000    -1.000000
# 25%    -300.000000  -350.000000    6.000000      0.000000    -1.000000
# 50%     161.000000   100.000000    7.000000      0.000000     3.000000
# 75%     211.000000   197.000000   12.000000      0.000000     8.500000
# max     300.000000   261.000000   12.000000      1.000000    51.000000
#
#           mint_cat  collection_cat
# count  1931.000000     1931.000000
# mean     37.541170    18483.665458
# std      24.924024    10860.066448
# min      -1.000000       -1.000000
# 25%      24.000000     9257.000000
# 50%      24.000000    18743.000000
# 75%      29.000000    27885.000000
# max     110.000000    37207.000000
#              Entity  id_coin
# 95             Kopf      853
# 21        Brustbild      668
# 103    Lorbeerkranz      646
# 35          Delphin      513
# 242         stehend      438
# 132          Panzer      364
# 223         erhoben      358
# 130    Paludamentum      340
# 154            Rind      300
# 67           Gewand      233
# 42         Dionysos      182
# 38          Demeter      158
# 144        Poseidon      156
# 48         Dreizack      152
# 59         Füllhorn      152
# 5    Antoninus Pius      149
# 100          Köcher      143
# 253      Ährenkranz      140
# 27        Caracalla      137
# 50        Efeukranz      131
# ##########
# Cluster 8
#          Unnamed: 0          coin      maxdiam      mindiam       weight  \
# count   2270.000000   2270.000000  2270.000000  1099.000000  2270.000000
# mean   20529.962996  22933.167401    20.159300    19.703094     7.247815
# std    11841.163342   8451.261742     7.184057     6.955854     6.403133
# min        0.000000  10253.000000     3.200000     7.000000     0.290000
# 25%    10489.250000  14916.250000    15.000000    15.000000     2.700000
# 50%    20660.000000  24361.500000    19.000000    18.000000     5.345000
# 75%    30680.500000  29012.500000    26.000000    25.000000     9.700000
# max    41073.000000  38129.000000    48.000000    47.000000    53.260000
#
#            enddate    startdate         axis  material_cat    denom_cat  \
# count  2270.000000  2270.000000  1111.000000   2270.000000  2270.000000
# mean    -27.423789   -63.461233     7.283528      0.399559     8.281057
# std     243.055656   261.489671     3.893363      0.889337    15.654808
# min    -550.000000  -600.000000     1.000000      0.000000    -1.000000
# 25%    -300.000000  -350.000000     6.000000      0.000000    -1.000000
# 50%      14.000000   -27.000000     7.000000      0.000000     1.000000
# 75%     211.000000   197.000000    12.000000      0.000000     4.000000
# max     330.000000   320.000000    12.000000      4.000000    51.000000
#
#           mint_cat  collection_cat
# count  2270.000000     2270.000000
# mean     56.561674    16799.180617
# std      30.175313    11638.177722
# min      -1.000000       -1.000000
# 25%      38.000000     6136.000000
# 50%      61.000000    16732.000000
# 75%      83.000000    27122.750000
# max     115.000000    37216.000000
#              Entity  id_coin
# 152            Kopf     1519
# 171    Lorbeerkranz     1148
# 33        Brustbild      814
# 361         haltend      503
# 207    Paludamentum      485
# 210          Panzer      451
# 382         stehend      425
# 101          Gewand      391
# 120            Helm      348
# 212          Patera      332
# 17           Athena      319
# 0             Adler      215
# 85         Füllhorn      213
# 12          Apollon      203
# 15          Artemis      194
# 256          Schild      174
# 139        Kalathos      168
# 36        Caracalla      165
# 8    Antoninus Pius      161
# 31            Bogen      156
# ##########
# Cluster 9
#          Unnamed: 0          coin      maxdiam      mindiam       weight  \
# count   2070.000000   2070.000000  2070.000000  1146.000000  2070.000000
# mean   20501.581159  30847.564251    22.676309    24.091972     9.600256
# std    11996.073846   6941.886296     7.693313     7.039064     8.218996
# min       19.000000   8484.000000     7.000000     7.000000     0.300000
# 25%    10152.000000  30037.250000    17.400000    17.700000     3.550000
# 50%    20443.500000  33592.500000    21.000000    24.950000     6.505000
# 75%    30653.750000  34392.750000    29.100000    29.200000    15.567500
# max    41071.000000  37842.000000    46.000000    43.000000    53.710000
#
#            enddate    startdate        axis  material_cat    denom_cat  \
# count  2070.000000  2070.000000  853.000000   2070.000000  2070.000000
# mean     22.545894     0.583575    8.978898      0.184541     4.387440
# std     227.205165   237.920680    3.548394      0.550717    10.770313
# min    -500.000000  -525.000000    1.000000      0.000000    -1.000000
# 25%    -225.000000  -245.000000    6.000000      0.000000    -1.000000
# 50%     161.000000   138.000000   12.000000      0.000000     1.000000
# 75%     217.000000   209.000000   12.000000      0.000000     4.000000
# max     300.000000   260.000000   12.000000      3.000000    51.000000
#
#           mint_cat  collection_cat
# count  2070.000000     2070.000000
# mean     69.817874    17270.997585
# std      25.901628    11301.907095
# min      -1.000000       -1.000000
# 25%      66.000000     7350.750000
# 50%      83.000000    17119.000000
# 75%      86.000000    27163.500000
# max     107.000000    37212.000000
#              Entity  id_coin
# 124            Kopf     1558
# 138    Lorbeerkranz     1159
# 32        Brustbild      650
# 168          Panzer      472
# 166    Paludamentum      463
# 39        Caracalla      387
# 170          Patera      354
# 280         haltend      316
# 205          Schild      277
# 104            Helm      257
# 6    Antoninus Pius      249
# 16           Athena      238
# 220           Speer      236
# 165       Palmzweig      219
# 74         Füllhorn      216
# 106        Herakles      209
# 62         Elagabal      206
# 146       Löwenfell      198
# 157            Nike      178
# 128           Kranz      166

# %%
data_entity.columns
# Out:
# Index(['id_coin', 'id_design', 'design_en', 'design_de', 'side', 'DesignID',
#        'Entity', 'Label_Entity'],
#       dtype='object')

# %%
data_sample0.describe()
# Out:
#          Unnamed: 0          coin      maxdiam      mindiam       weight  \
# count   1625.000000   1625.000000  1625.000000  1422.000000  1625.000000
# mean   20599.113231  11307.354462    20.126172    19.879592     7.048474
# std    11702.516041  11135.690960     6.502319     6.396083     5.239312
# min       60.000000   6363.000000     7.000000     8.000000     0.450000
# 25%    10299.000000   6811.000000    15.000000    14.000000     2.590000
# 50%    20619.000000   7309.000000    20.000000    20.000000     6.070000
# 75%    30305.000000   7940.000000    25.000000    25.000000    10.410000
# max    41052.000000  41902.000000    42.000000    42.000000    60.310000
#
#            enddate    startdate         axis  material_cat    denom_cat  \
# count  1625.000000  1625.000000  1055.000000   1625.000000  1625.000000
# mean   -124.270154  -161.395692     7.579147      0.433846    13.748923
# std     256.020012   267.270143     4.038611      0.528229    15.622580
# min    -500.000000  -540.000000     1.000000      0.000000    -1.000000
# 25%    -336.000000  -365.000000     5.000000      0.000000     0.000000
# 50%    -215.000000  -286.000000     7.000000      0.000000     4.000000
# 75%     210.000000   193.000000    12.000000      1.000000    25.000000
# max     300.000000   253.000000    12.000000      4.000000    51.000000
#
#           mint_cat  collection_cat
# count  1625.000000     1625.000000
# mean     47.641231    18477.163692
# std      33.037762    10868.411087
# min      -1.000000       -1.000000
# 25%      15.000000     9030.000000
# 50%      52.000000    18418.000000
# 75%      70.000000    28039.000000
# max     115.000000    37215.000000

# %%
data_entity_agg = data_entity_sample0.groupby("Entity")["id_coin"].count().reset_index()
data_entity_agg = data_entity_agg.sort_values("id_coin", ascending=False)
data_entity_agg.head(20)
# Out:
#            Entity  id_coin
# 117          Kopf     1095
# 134  Lorbeerkranz      475
# 26      Brustbild      391
# 308       haltend      322
# 165  Paludamentum      313
# 297       erhoben      290
# 328       stehend      284
# 85          Greif      276
# 168        Panzer      275
# 97       Herakles      239
# 78         Gewand      232
# 10        Apollon      209
# 140     Löwenfell      206
# 83        Gordian      188
# 14         Athena      150
# 282        Zepter      149
# 332      thronend      148
# 326     springend      145
# 45       Dionysos      141
# 95           Helm      137
