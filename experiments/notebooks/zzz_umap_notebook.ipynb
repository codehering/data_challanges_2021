# %%
import numpy as np
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline

# %%
sns.set(style='white', context='notebook', rc={'figure.figsize':(14,10)})

# %%
data = pd.read_csv('data\\analysis_dataset.csv', sep=";")
data = data.dropna()

# %%
data.describe()
# Out:
#          Unnamed: 0          coin      maxdiam      mindiam       weight  \
# count   5947.000000   5947.000000  5947.000000  5947.000000  5947.000000
# mean   20555.791155  13190.413318    22.638572    22.056408     9.066516
# std    11889.223994  12367.686653     7.238582     7.151399     7.545908
# min       11.000000     41.000000     0.700000     0.700000     0.120000
# 25%    10157.000000   4157.000000    17.000000    16.850000     3.520000
# 50%    20727.000000   6821.000000    22.000000    22.000000     6.790000
# 75%    30799.000000  18259.500000    28.500000    28.000000    13.960000
# max    41078.000000  41964.000000    48.000000    47.000000    64.320000
#
#            enddate    startdate         axis  material_ ae   material_ ar   \
# count  5947.000000  5947.000000  5947.000000    5947.000000    5947.000000
# mean     19.536573   -11.971078     7.085758       0.824617       0.163612
# std     233.549261   251.033218     3.869731       0.380326       0.369954
# ...

# %%
# make material great again
mat_cols = [x for x in data.columns.tolist() if "material" in x]
data["material"] = 0
i = 1
for c in mat_cols:
    data["material"] = np.where(data[c]==1, i, data["material"])
    i +=1
    del data[c]

# %%
data.describe()
# Out:
#          Unnamed: 0          coin      maxdiam      mindiam       weight  \
# count   5947.000000   5947.000000  5947.000000  5947.000000  5947.000000
# mean   20555.791155  13190.413318    22.638572    22.056408     9.066516
# std    11889.223994  12367.686653     7.238582     7.151399     7.545908
# min       11.000000     41.000000     0.700000     0.700000     0.120000
# 25%    10157.000000   4157.000000    17.000000    16.850000     3.520000
# 50%    20727.000000   6821.000000    22.000000    22.000000     6.790000
# 75%    30799.000000  18259.500000    28.500000    28.000000    13.960000
# max    41078.000000  41964.000000    48.000000    47.000000    64.320000
#
#            enddate    startdate         axis    denom_cat     mint_cat  \
# count  5947.000000  5947.000000  5947.000000  5947.000000  5947.000000
# mean     19.536573   -11.971078     7.085758     7.819573    47.617454
# std     233.549261   251.033218     3.869731    14.739066    36.252888
# ...

# %%
sns.pairplot(data, hue='material')
# Out:
# C:\Users\fredi\Anaconda3\envs\ftp\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\fredi\Anaconda3\envs\ftp\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)

# %%
import umap.umap_ as umap
reducer = umap.UMAP()
scaled_data = StandardScaler().fit_transform(data)
embedding = reducer.fit_transform(scaled_data)
embedding.shape
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-13-07846a898ab3> in <module>
# ----> 1 import umap.umap_ as umap
#       2 reducer = umap.UMAP()
#       3 scaled_data = StandardScaler().fit_transform(data)
#       4 embedding = reducer.fit_transform(scaled_data)
#       5 embedding.shape
#
# ModuleNotFoundError: No module named 'umap.umap_'; 'umap' is not a package
